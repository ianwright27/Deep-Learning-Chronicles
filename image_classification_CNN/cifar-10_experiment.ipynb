# %%
# Experiments with the CIFAR-10 Dataset

# %% [markdown]
# ## The CIFAR-10 Dataset: An Overview
#
# The **CIFAR-10 dataset** is a widely used collection of images for training machine learning models, particularly for image classification tasks using **Convolutional Neural Networks (CNNs)**. It serves as a more complex alternative to the simpler MNIST dataset.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt


# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Print the shape of the training data
print(train_images.shape)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 280s 2us/step
# (50000, 32, 32, 3)
